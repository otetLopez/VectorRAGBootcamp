# %% [markdown]
# # Cohere Document Search with Langchain

# %% [markdown]
# This example shows how to use the Python [langchain](https://python.langchain.com/docs/get_started/introduction) library to run a text-generation request against [Cohere's](https://cohere.com/) API, then augment that request using the text stored in a collection of local PDF documents.
#
# **Requirements:**
# - You will need an access key to Cohere's API key, which you can sign up for at (https://dashboard.cohere.com/welcome/login). A free trial account will suffice, but will be limited to a small number of requests.
# - After obtaining this key, store it in plain text in your home in directory in the `~/.cohere.key` file.
# - (Optional) Upload some pdf files into the `source_documents` subfolder under this notebook. We have already provided some sample pdfs, but feel free to replace these with your own.

# %% [markdown]
# ## Set up the RAG workflow environment

# %%
from getpass import getpass
import os
from pathlib import Path

from langchain.chains import RetrievalQA
from langchain.chat_models import ChatCohere
from langchain.document_loaders import TextLoader
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain.llms import Cohere
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import CohereRerank
from langchain.schema import HumanMessage, SystemMessage
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS

# %% [markdown]
# Set up some helper functions:

# %%
def pretty_print_docs(docs):
    print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

# %% [markdown]
# Make sure other necessary items are in place:

# %%
##  Set up all of the parameters here
##

#directory_path = "./rfp_documents"
#directory_path = "./sf_documents"
#directory_path = "./ats_documents"
directory_path = "./ats_fr_montreal_documents"

multilingual_mode= True
chunk_size=1000
rerank_top_n = 15

if multilingual_mode:
    embeddings_model="embed-multilingual-light-v3.0"
else:
    embeddings_model="embed-english-light-v3.0"

#query = "What are the different modes for junction management or conflict convergence?"
#query = "List requirements for route diversions and rerouting."
#query = "List requirements for online or runtime timetable editing."
#query = "Does the Montreal Blue Line spec contain any requirements for editing a timetable at runtime vs offline?"
query = "List any requirements for editing a timetable at runtime vs offline?"

# %%
try:
    os.environ["COHERE_API_KEY"] = open(Path.home() / ".cohere.key", "r").read().strip()
except Exception:
    print(f"ERROR: You must have a Cohere API key available in your home directory at ~/.cohere.key")

# Look for the source_documents folder and make sure there is at least 1 pdf file here
contains_pdf = False

if not os.path.exists(directory_path):
    print(f"ERROR: The {directory_path} subfolder must exist under this notebook")
for filename in os.listdir(directory_path):
    contains_pdf = True if ".pdf" in filename else contains_pdf
    if ".pdf" in filename:
       print(f"found {filename}")
if not contains_pdf:
    print(f"ERROR: The {directory_path} subfolder must contain at least one .pdf file")
# Out:
# found Montreal-Blue-Line-ATS-Specs-French.pdf
# found File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf

# %% [markdown]
# ## Start with a basic generation request without RAG augmentation
#
# Let's start by asking the Cohere LLM a difficult, domain-specific question we don't expect it to have an answer to. A simple question like "*What is the capital of France?*" is not a good question here, because that's basic knowledge that we expect the LLM to know.
#
# Instead, we want to ask it a question that is very domain-specific that it won't know the answer to. A good example would an obscure detail buried deep within a company's annual report. For example:
#
# "*How many Vector scholarships in AI were awarded in 2022?*"

# %% [markdown]
# ## Now send the query to Cohere

# %%
from langchain_core.messages import HumanMessage
#llm = Cohere()
llm = ChatCohere(model="command-r")
#result = llm(query)([HumanMessage(content=message)])
#print(f"Result: \n\n{result}"
# result = llm(query)
# print(f"Result: \n\n{result}")

# %% [markdown]
# ## Ingestion: Load and store the documents from source_documents

# %% [markdown]
# Start by reading in all the PDF files from `source_documents`, break them up into smaller digestible chunks, then encode them as vector embeddings.

# %%
# Load the pdfs
loader = PyPDFDirectoryLoader(directory_path)
docs = loader.load()
print(f"Number of source materials: {len(docs)}")

# Split the documents into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=200)
chunks = text_splitter.split_documents(docs)
print(f"Number of text chunks: {len(chunks)}")

# Define the embeddings model
#model_name = "BAAI/bge-small-en-v1.5"
#encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the embeddings model...")
#embeddings = HuggingFaceBgeEmbeddings(
#    model_name=model_name,
#    model_kwargs={'device': 'cuda'},
#    encode_kwargs=encode_kwargs
#)

from langchain_community.embeddings.cohere import CohereEmbeddings

embeddings = CohereEmbeddings(model=embeddings_model)

print(f"Done")
# Out:
# Number of source materials: 94
# Number of text chunks: 352
# Setting up the embeddings model...
# Done

# %% [markdown]
# # Retrieval: Make the document chunks available via a retriever

# %% [markdown]
# The retriever will identify the document chunks that most closely match our original query. (This takes about 1-2 minutes)

# %%
vectorstore = FAISS.from_documents(chunks, embeddings)
retriever = vectorstore.as_retriever(search_kwargs={"k": 20})

# %% [markdown]
# Let's see what results it found. Important to note, these results are in the order the retriever thought were the best matches.

# %%
# Retrieve the most relevant context from the vector store based on the query(No Reranking Applied)
docs = retriever.get_relevant_documents(query)

# %%
pretty_print_docs(docs)
# Out:
# Document 1:
#
# shall be loaded from a Configurable star t time set by the Transportation Controller.
# 13. The ATS subsystem shall have schedule editing tool s to modify the timetable database prior and
# during run time to account for potential changes or  during operations (i.e., changing timepoints, re-
# baselining the schedule, service imp acts/cancellations, special events).
# a. The ATS subsystem shall have functional interf aces to synchronize schedule changes made in
# ATS to OrbCAD as described in Section 28 (Interface Requirements Specifications).
# b. The ATS subsystem shall modify the timetabl e database during run time to process same-day
# schedule changes received from OrbCAD in or der to remain synchronized between OrbCAD
# and ATS.
# c. Contractor shall confer with SFMTA during the Design Phase and confirm the specific
# schedule editing tools needed to meet Contr act requirements and SFMTA’s operational needs
# as described in the Concept of Operations and Maintenance.
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# Release 1.1- 4/25/2023 Release 1.2- 6/5/2023
# SFMTA P-600 (11-21) – FTA A-212 SFMTA-2022-40-FTA
# KL                    n:\ptc\as2023\2100392\01654703.docx 2/6/23
# 14. The ATS timetable storage and database function shall use the loaded/ac tive ATS timetable to
# automatically:
# a. Generate, populate, and display the daily  train schedules for all lines/services
# b. Provide the schedule data to drive the automa tic ATS trip assignment function where trips get
# automatically assigned to trains that are located at the specified/defined train origination/entry
# points in the ATS monitored territory
# c. Provide the routing assignment based  on the train’s trip assignment
# 15. The schedule editing tools shall create new schedules by modifying existing schedules.
# 16. The schedule editing tools shall determine, modify , and save service routes, which establish routing
# through the System, to be applied and incorpor ated into new and existing schedules/services.
# ----------------------------------------------------------------------------------------------------
# Document 3:
#
# Saturday/Sunday schedule is attempte d to be populated onto a weekday.
# 8. The System shall have a GUI to import, manage and program schedules into the electronic calendar.
# 9. The ATS subsystem timetable storage and datab ase function shall assemble and populate the daily
# train reporting sheet function when a time table is loaded in the ATS System.
# 10. The ATS subsystem shall automatically load the dail y timetable with the electronic calendar function.
# 11. The ATS subsystem shall allow Transportation Cont rollers to manually load a daily timetable by
# selecting a specific timetable database file. This feature will override the automatically loaded
# timetable for that day.
# 12. When the timetable is automatically  loaded by the calendar function, the full-day's train trip schedule
# shall be loaded from a Configurable star t time set by the Transportation Controller.
# 13. The ATS subsystem shall have schedule editing tool s to modify the timetable database prior and
# ----------------------------------------------------------------------------------------------------
# Document 4:
#
# database.
# 6. The ATS subsystem shall have a timetable storage and database function that supports the storage of
# a minimum of one calendar year’s worth of schedules, comprised, and categorized as weekday,
# Saturday, Sunday, Holiday, and special event schedul es that can be populated (programmed) into an
# electronic calendar (load-schedule-by-calendar-dat e function) up to one year in advance.
# 7. The ATS subsystem shall use predetermined sche duling rules and apply automatic error checks
# without a user-confirmation when populating schedules into the electronic calendar.
# a. An example of an error-check without user confirmation would be to prevent a weekday
# schedule from being populated onto a Saturday or Sunday.
# b. An example of an error-check that requi res a user confirmation would be when a
# Saturday/Sunday schedule is attempte d to be populated onto a weekday.
# 8. The System shall have a GUI to import, manage and program schedules into the electronic calendar.
# ----------------------------------------------------------------------------------------------------
# Document 5:
#
# Release 1.1- 4/25/2023 Release 1.2- 6/5/2023
# SFMTA P-600 (11-21) – FTA A-211 SFMTA-2022-40-FTA
# KL                    n:\ptc\as2023\2100392\01654703.docx 2/6/23
# specified deviation tolerance before manual action (e .g., adjust trip departure time, reassign/swap trip,
# cancel trip) is required by the Transportation Controllers.
# 3. The ATR function shall regulate train schedul e performance by maintaining schedule/headway
# adherence at each scheduled arrival and departure timepoint.
# 4. The ATS subsystem shall import, accept and pr ocess timetable databases produced by Trapeze and
# OrbCAD. Interface requirements to these Third-Part y Systems are specified in Section 28 (Interface
# Requirements Specifications).
# 5. The ATS subsystem shall store imported timetabl es from Third-Party Systems in its timetable
# database.
# 6. The ATS subsystem shall have a timetable storage and database function that supports the storage of
# ----------------------------------------------------------------------------------------------------
# Document 6:
#
# c) Manœuvre finale au terminus de destination (incluant le quai d’arrivée);
# d) Matricule opérateur;
# e) Origine;
# f) Destination;
# g) État de la course (future, en cours, terminée);
# h) Type de course (HLP, voyageur);
# i) Plage horaire (heure de début et de fin).
# 5.7.4. MODIFIER LA TABLE HORAIRE D’EXPLOITATION
#  [R] L’ATS CBTC doit s’assurer que pour toute modification effectuée à la table horaire, celle-ci reste
# opérationnelle et permet d’assurer le maintien des automatismes d’opération.
# 5.7.4.1. Modification de l’heure de départ
#  [R] L’ATS CBTC doit permettre de modifier l’heure de départ d’une course à venir via une commande
# de l’IPM tant que la séquence de départ n’est pas commencée.
#  [I] La séquence de départ correspond à l’ensemble des commandes requises pour autoriser le départ
# d’un train d’un terminus (ex. timbre de départ, itinéraire, indicateur de départ) qui est envoyé en
# ----------------------------------------------------------------------------------------------------
# Document 7:
#
# physiques) du système à intervalle régulier au travers de l’interface avec l’Historien TCPE
# ([VolC_PO1_S11]  - Volume C – Partie 1 - Section S11- Exigences Relatives aux interfaces CC).
#  [R] L’ATS CBTC doit exporter les journaux applicatifs et du système d’exploitation de chacune des
# machines (virtuelles ou physiques) à intervalle régulier au travers de l’interface avec l’Historien TCPE
# ([VolC_PO1_S11]  - Volume C – Partie 1 - Section S11- Exigences Relatives aux interfaces CC).
#  [R] Les événements archivés doivent être dans un format compréhensible par un utilisateur
# possédant le dictionnaire adéquat, permettant la traduction de la structure de données.
#  [L] Le dictionnaire permettant la traduction de la structure de données des événements doit être
# soumis au Représentant désigné pour Vérification.
#  [R] Dans le cas où l’ATS CBTC archive sur un support longue durée, les échanges avec le système
# ----------------------------------------------------------------------------------------------------
# Document 8:
#
# tous les trains dont la course est complétée et changer le mode de départ des terminus à « hors
# service ».
# 5.7.6. MODIFIER LES HORAIRES HORS-LIGNE
#  [R] L’ATS CBTC doit permettre de visualiser une table horaire sans la charger pour l’exploitation
# (hors-ligne) via l’IPM.
#  [R] L’ATS CBTC doit fournir les outils nécessaires à l’IPM pour modifier un horaire hors-ligne et en
# vérifier la cohérence. Les mêmes commandes de modifications que pour un horaire chargé doivent
# être disponibles.
#  [R] L’ATS CBTC doit afficher une alarme à l’IPM lorsqu’une modification de l’horaire induit une
# incohérence.
#  [R] Lorsque les modifications faites à une table horaire hors-ligne sont valides, l’ATS CBTC doit
# permettre de sauvegarder les modifications pour utilisation ultérieure.
# 5.7.7. ARCHIVER LES DONNÉES D’EXPLOITATION
#  [R] L’ATS CBTC doit archiver toutes les données des horaires réalisés incluant, au minimum,
# ----------------------------------------------------------------------------------------------------
# Document 9:
#
# [R] L’ATS CBTC doit présenter la table horaire triée par ordre chronologique des heures de départ.
#  [R] L’ATS CBTC doit permettre de mettre à jour automatiquement le format et la couleur de champs
# de la table horaire en fonction de critères prédéfinis (ex. : type de course, état de la course).
#  [L] La définition des couleurs utilisées dans la table horaire pour les différents états/types de courses
# doit être soumise au Représentant désigné pour Vérification.
#  [R] L’ATS CBTC doit permettre d’afficher à l’IPM un horaire d’exploitation qui s’étend sur 2 jours (ex. :
# période d’exploitation de 5 h AM à 2 h AM le lendemain).
#  [R] L’ATS CBTC doit permettre, au minimum, de filtrer la table horaire en fonction des critères
# suivants :
# a) Numéro de tournée;
# b) Manœuvre initiale au terminus d’origine (incluant le quai de départ);
# c) Manœuvre finale au terminus de destination (incluant le quai d’arrivée);
# d) Matricule opérateur;
# e) Origine;
# f) Destination;
# ----------------------------------------------------------------------------------------------------
# Document 10:
#
# 5.7. GÉRER LES HORAIRES DE TRAIN ............................................................................. 29
# 5.7.1. RÉCUPÉRER LES HORAIRES D’EXPLOITATION .......................................................................... 29
# 5.7.2. CHARGER LA TABLE HORAIRE D’EXPLOITATION ....................................................................... 30
# 5.7.3. VISUALISER L’HORAIRE D’EXPLOITATION ................................................................................... 30
# 5.7.4. MODIFIER LA TABLE HORAIRE D’EXPLOITATION........................................................................ 31
# 5.7.5. GÉRER LES COURSES DE TRAIN .................................................................................................. 35
# 5.7.6. MODIFIER LES HORAIRES HORS-LIGNE ...................................................................................... 35
# ----------------------------------------------------------------------------------------------------
# Document 11:
#
# automatically.
# 4. The ATS GUI shall have a command to immediatel y deactivate one or multiple Train Depart Local
# Control Consoles.
# 5. The ATS subsystem shall indicate on the line overvie w and train tracking displays each Train Depart
# Local Control Console’s activation status, including the activation start and end time.
# 17.7.5  CUSTOMER INFORMATION SYSTEMS
# 1. The ATS subsystem shall interface with the onb oard passenger information system via API as
# specified in Section 28 (Interface Requirements Specifications) to activate pre-written and pre-
# recorded visual and audio message announcements such  as next station, destination, and public safety
# announcements.
# 2. To enable passenger information display systems to  operate on station platforms, the ATS subsystem
# shall provide the predicted train arrival time, along with train Line Assignment and other identifying
# information for every station/timepoint in CBTC Territory to Third-Party Systems.
# ----------------------------------------------------------------------------------------------------
# Document 12:
#
# m. Implement Schedule Management functions.
# n. Implement Daily train reporting function.
# o. Implement Automatic Train Regulation functions.
# p. Set, display, and remove Temporary Speed R estrictions as specified in Section 16.3.1.9
# (Temporary Speed Restrictions).
# q. Set, display, and remove Work Zones as specifi ed in Section 16.3.1.10 (Worker Protection)
# r. Prevent overloading of power and ventilation sections by restricting the number of trains that
# can enter or operate in a de fined power/ventilation section.
# s. Interface with physical Emergency Stop Buttons, pl atform Local Control Panels and platform
# Train Depart Consoles as specified in Secti on 16.3.1 (Train Control and Supervision).
# t. Interface with Third-Party Systems as specified in Section 28 (Interface Requirements
# Specifications).
# u. Archive and timestamp all ATS events categorized as follows:
# i. all ATS commands and acti ons applied or executed manually or automatically
# ----------------------------------------------------------------------------------------------------
# Document 13:
#
# ii. duration and reaction of alarms (for ex ample: does alarm latch until manually
# cleared, how long will the alarm be displayed or sounded for)
# iii. alarm category (by criticality and severity)
# iv. alarm type (e.g., System, operational, maintenance) via text or open format
# Configuration files
# 4. The ATS subsystem shall display alarms thr ough an always visible alarm banner on the
# Transportation Controller workstations.  The alarm banner shall display all operation critical alarms
# in order of severity.
# 5. The ATS Human Factors Analysis and Review Docume nt [CDRL] shall include an analysis of the
# alarm banner design and the fault reporting and alarm function.
# 6. The ATS subsystem shall have an events viewer f unction that filters viewing and searching of alarm
# events.
# 7. Audio alarms shall have a fixed volume that is C onfigurable by SFMTA user role (including mute).
# Users shall not be able to configure their own volume.
# ----------------------------------------------------------------------------------------------------
# Document 14:
#
# Specifications).
# u. Archive and timestamp all ATS events categorized as follows:
# i. all ATS commands and acti ons applied or executed manually or automatically
# ii. all Interlocking status and changes
# iii. all CBTC-driven status and changes
# ----------------------------------------------------------------------------------------------------
# Document 15:
#
# sauvegarder pour une réutilisation ultérieure en spécifiant le nom de la nouvelle table horaire.
# 5.7.5. GÉRER LES COURSES DE TRAIN
#  [R] L’ATS CBTC doit initier le processus de gestion automatique des trains dès qu’une table horaire
# est chargée et active ou qu’un terminus passe en mode de régulation par intervalle (ex. numérotation,
# acheminement des trains, gestion des départs, régulation).  Pour plus de détails sur les modes de
# départ « horaire » , voir 5.9 - Gérer les départs et manœuvres en terminus.
#  [R] L’ATS CBTC doit arrêter le processus de gestion automatique des trains dès qu’un terminus
# passe en mode « hors service », à l’exception des courses en cours qui doivent être complétées.
#  [R] Suite au déchargement de la table horaire, l’ATS CBTC doit supprimer le numéro de tournée de
# tous les trains dont la course est complétée et changer le mode de départ des terminus à « hors
# service ».
# 5.7.6. MODIFIER LES HORAIRES HORS-LIGNE
# ----------------------------------------------------------------------------------------------------
# Document 16:
#
# time and provide an adherence report to SFMTA through the analytics tools.
# 23. The computed variation from schedule for each trai n in CBTC Territory that is regulated by schedule
# adherence shall be displayed on the ATS GUI and represented graphically indicating the following
# train conditions:
# a. Ahead of schedule
# b. On schedule – 2 minutes late
# c. 2-5 minutes late
# d. 5 or more minutes late
# 24. The computed variation from headway for each trai n in CBTC Territory that is regulated by headway
# adherence shall be displayed on the ATS GUI and represented graphically indicating the following
# train conditions:
# a. Bunched (headway is shorter than assi gned headway by more than 2 minutes)
# b. On headway (within plus or minus 2 minutes)
# c. Gapped (headway is longer than assigned headway by more than 2 minutes)
# 17.5.2  ATS  SCHEDULE MANAGEMENT FUNCTION
# 1. The ATS subsystem shall have a schedule manageme nt system where train service and operations are
# ----------------------------------------------------------------------------------------------------
# Document 17:
#
# through the System, to be applied and incorpor ated into new and existing schedules/services.
# 17. The ATS timetable storage and database function shall have a repository for schedules and route
# definitions.
# 18. The ATS subsystem shall allow manual assignment or re-assignment of trips to any station platform
# or stop in CBTC Territory.
# 19. The ATS subsystem shall include a function by whic h Transportation Controllers can edit and delete
# existing trips and create or add unscheduled trains  and trips in real-time during Revenue Service.
# 20. The ATS subsystem shall track, record, and report for display all trips in the daily schedule, all trips
# that are assigned to a train, all trips that are in progress, all trips that are completed, and all
# modifications performed on a trip.
# 21. The ATS subsystem shall include a function by whic h Transportation Controllers can trace a trip back
# to its original trip assignment and routing assignments.
# ----------------------------------------------------------------------------------------------------
# Document 18:
#
# point.
# c. A command allowing the user to modify prev iously assigned Dwell Times at a specific stop,
# station, platform, or layover point.
# d. The Dwell Time assignment command shall enable  the user to specify the time period the
# Dwell Time assignments are effective. Users sha ll also be able to specify the Dwell Time
# assignment is in effect indefinitely.
# e. The Dwell Time assignment and modification comm ands shall enable the user to specify
# which trains the assigned Dwell Times apply to . The commands shall provide the following
# options:
# i. Specify individual trains identified by Consist ID.
# f. Specify the next “n” trains arriving at the stop, station, platform, or layover point, where “n”
# is a number of trains. .
# i. Specify all trains arriving at the stop, station, platform, or layover point.
# g. A message to Third-Party Systems through the API as described in Section 28 (Interface
# Management Specifications) communicating the set Dwell Times for each stop, station,
# ----------------------------------------------------------------------------------------------------
# Document 19:
#
# sera faite en collaboration avec la STM.
#  [R] Dans le cas où l’ATS CBTC archive sur un support longue durée (option a) de l’exigence
# 5.18.2.0.1), seuls les événements dont la date d’apparition dépasse un seuil configurable doivent
# être archivés sur le support de longue durée (ex. événements datant de plus de trois jours).
#  [R] Dans le cas où l’ATS CBTC archive sur un support longue durée, l’ATS CBTC doit effacer les
# données locales lorsque celles-ci ont été archivées sur le support de longue durée.
#  [R] L’ATS CBTC doit archiver tous les fichiers contenant les traces et les erreurs de toutes les
# applications logicielles des IPM.
# ----------------------------------------------------------------------------------------------------
# Document 20:
#
# for each Line and train service.
# b. Applicable data fields of the daily train repor ting sheet shall be automatically populated and
# derived from the loaded daily timetable schedule.
# c. Contractor shall design and develop, with SFMTA input, the appearance and layout of the
# daily train reporting sheet. Contractor shall include the daily train reporting sheet in the ATS Design Description Document [CDRL].
# d. The daily train reporting sheet function shall k eep track of deviations between the daily
# scheduled service and the actual service delivered by each assigned trip and service.

# %% [markdown]
# These results seem to somewhat match our original query, but we still can't seem to find the information we're looking for. Let's try sending our LLM query again including these results, and see what it comes up with.

# %%
#print(f"Sending the RAG generation with query: {query}")
#qa = RetrievalQA.from_chain_type(llm=llm,
#        chain_type="stuff",
#        retriever=retriever)
#print(f"Result:\n\n{qa.run(query=query)}")

# %% [markdown]
# # Reranking: Improve the ordering of the document chunks

# %%
#compressor = CohereRerank(top_n=15)
if multilingual_mode:
    compressor = CohereRerank(top_n=rerank_top_n, model="rerank-multilingual-2")
else:
    compressor = CohereRerank(top_n=rerank_top_n)
    
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=retriever
)

compressed_docs = compression_retriever.get_relevant_documents(query)

# %%
compressed_docs
# Out:
# [Document(page_content='tous les trains dont la course est complétée et changer le mode de départ des terminus à «\u2009hors \nservice\u2009». \n5.7.6. MODIFIER LES HORAIRES HORS-LIGNE \n [R] L’ATS CBTC doit permettre de visualiser une table horaire sans la charger pour l’exploitation \n(hors-ligne) via l’IPM. \n [R] L’ATS CBTC doit fournir les outils nécessaires à l’IPM pour modifier un horaire hors-ligne et en \nvérifier la cohérence. Les mêmes commandes de modifications que pour un horaire chargé doivent \nêtre disponibles. \n [R] L’ATS CBTC doit afficher une alarme à l’IPM lorsqu’une modification de l’horaire induit une \nincohérence. \n [R] Lorsque les modifications faites à une table horaire hors-ligne sont valides, l’ATS CBTC doit \npermettre de sauvegarder les modifications pour utilisation ultérieure. \n5.7.7. ARCHIVER LES DONNÉES D’EXPLOITATION \n [R] L’ATS CBTC doit archiver toutes les données des horaires réalisés incluant, au minimum,', metadata={'source': 'ats_fr_montreal_documents/Montreal-Blue-Line-ATS-Specs-French.pdf', 'page': 34, 'relevance_score': 0.9233162}),
#  Document(page_content='shall be loaded from a Configurable star t time set by the Transportation Controller. \n13. The ATS subsystem shall have schedule editing tool s to modify the timetable database prior and \nduring run time to account for potential changes or  during operations (i.e., changing timepoints, re-\nbaselining the schedule, service imp acts/cancellations, special events). \na. The ATS subsystem shall have functional interf aces to synchronize schedule changes made in \nATS to OrbCAD as described in Section 28 (Interface Requirements Specifications). \nb. The ATS subsystem shall modify the timetabl e database during run time to process same-day \nschedule changes received from OrbCAD in or der to remain synchronized between OrbCAD \nand ATS. \nc. Contractor shall confer with SFMTA during the Design Phase and confirm the specific \nschedule editing tools needed to meet Contr act requirements and SFMTA’s operational needs \nas described in the Concept of Operations and Maintenance.', metadata={'source': 'ats_fr_montreal_documents/File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf', 'page': 13, 'relevance_score': 0.5733201}),
#  Document(page_content='c) Manœuvre finale au terminus de destination (incluant le quai d’arrivée); \nd) Matricule opérateur; \ne) Origine; \nf) Destination; \ng) État de la course (future, en cours, terminée); \nh) Type de course (HLP, voyageur); \ni) Plage horaire (heure de début et de fin). \n5.7.4. MODIFIER LA TABLE HORAIRE D’EXPLOITATION \n [R] L’ATS CBTC doit s’assurer que pour toute modification effectuée à la table horaire, celle-ci reste \nopérationnelle et permet d’assurer le maintien des automatismes d’opération. \n5.7.4.1. Modification de l’heure de départ \n [R] L’ATS CBTC doit permettre de modifier l’heure de départ d’une course à venir via une commande \nde l’IPM tant que la séquence de départ n’est pas commencée. \n [I] La séquence de départ correspond à l’ensemble des commandes requises pour autoriser le départ \nd’un train d’un terminus (ex. timbre de départ, itinéraire, indicateur de départ) qui est envoyé en', metadata={'source': 'ats_fr_montreal_documents/Montreal-Blue-Line-ATS-Specs-French.pdf', 'page': 30, 'relevance_score': 0.08050192}),
#  Document(page_content='sauvegarder pour une réutilisation ultérieure en spécifiant le nom de la nouvelle table horaire. \n5.7.5. GÉRER LES COURSES DE TRAIN \n [R] L’ATS CBTC doit initier le processus de gestion automatique des trains dès qu’une table horaire \nest chargée et active ou qu’un terminus passe en mode de régulation par intervalle (ex. numérotation, \nacheminement des trains, gestion des départs, régulation).  Pour plus de détails sur les modes de \ndépart «\u2009horaire\u2009» , voir 5.9 - Gérer les départs et manœuvres en terminus. \n [R] L’ATS CBTC doit arrêter le processus de gestion automatique des trains dès qu’un terminus \npasse en mode «\u2009hors service\u2009», à l’exception des courses en cours qui doivent être complétées. \n [R] Suite au déchargement de la table horaire, l’ATS CBTC doit supprimer le numéro de tournée de \ntous les trains dont la course est complétée et changer le mode de départ des terminus à «\u2009hors \nservice\u2009». \n5.7.6. MODIFIER LES HORAIRES HORS-LIGNE', metadata={'source': 'ats_fr_montreal_documents/Montreal-Blue-Line-ATS-Specs-French.pdf', 'page': 34, 'relevance_score': 0.005099818}),
#  Document(page_content='Release 1.1- 4/25/2023 Release 1.2- 6/5/2023  \nSFMTA P-600 (11-21) – FTA A-212 SFMTA-2022-40-FTA \nKL                    n:\\ptc\\as2023\\2100392\\01654703.docx 2/6/23   \n14. The ATS timetable storage and database function shall use the loaded/ac tive ATS timetable to \nautomatically: \na. Generate, populate, and display the daily  train schedules for all lines/services \nb. Provide the schedule data to drive the automa tic ATS trip assignment function where trips get \nautomatically assigned to trains that are located at the specified/defined train origination/entry \npoints in the ATS monitored territory \nc. Provide the routing assignment based  on the train’s trip assignment \n15. The schedule editing tools shall create new schedules by modifying existing schedules. \n16. The schedule editing tools shall determine, modify , and save service routes, which establish routing \nthrough the System, to be applied and incorpor ated into new and existing schedules/services.', metadata={'source': 'ats_fr_montreal_documents/File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf', 'page': 14, 'relevance_score': 0.0012693645}),
#  Document(page_content='[R] L’ATS CBTC doit présenter la table horaire triée par ordre chronologique des heures de départ. \n [R] L’ATS CBTC doit permettre de mettre à jour automatiquement le format et la couleur de champs \nde la table horaire en fonction de critères prédéfinis (ex. : type de course, état de la course). \n [L] La définition des couleurs utilisées dans la table horaire pour les différents états/types de courses \ndoit être soumise au Représentant désigné pour Vérification. \n [R] L’ATS CBTC doit permettre d’afficher à l’IPM un horaire d’exploitation qui s’étend sur 2 jours (ex. : \npériode d’exploitation de 5 h AM à 2 h AM le lendemain). \n [R] L’ATS CBTC doit permettre, au minimum, de filtrer la table horaire en fonction des critères \nsuivants : \na) Numéro de tournée; \nb) Manœuvre initiale au terminus d’origine (incluant le quai de départ); \nc) Manœuvre finale au terminus de destination (incluant le quai d’arrivée); \nd) Matricule opérateur; \ne) Origine; \nf) Destination;', metadata={'source': 'ats_fr_montreal_documents/Montreal-Blue-Line-ATS-Specs-French.pdf', 'page': 30, 'relevance_score': 0.0008009536}),
#  Document(page_content='5.7. GÉRER LES HORAIRES DE TRAIN ............................................................................. 29  \n5.7.1. RÉCUPÉRER LES HORAIRES D’EXPLOITATION .......................................................................... 29  \n5.7.2. CHARGER LA TABLE HORAIRE D’EXPLOITATION ....................................................................... 30  \n5.7.3. VISUALISER L’HORAIRE D’EXPLOITATION ................................................................................... 30  \n5.7.4. MODIFIER LA TABLE HORAIRE D’EXPLOITATION........................................................................ 31  \n5.7.5. GÉRER LES COURSES DE TRAIN .................................................................................................. 35  \n5.7.6. MODIFIER LES HORAIRES HORS-LIGNE ...................................................................................... 35', metadata={'source': 'ats_fr_montreal_documents/Montreal-Blue-Line-ATS-Specs-French.pdf', 'page': 1, 'relevance_score': 0.0002082501}),
#  Document(page_content='through the System, to be applied and incorpor ated into new and existing schedules/services. \n17. The ATS timetable storage and database function shall have a repository for schedules and route \ndefinitions. \n18. The ATS subsystem shall allow manual assignment or re-assignment of trips to any station platform \nor stop in CBTC Territory. \n19. The ATS subsystem shall include a function by whic h Transportation Controllers can edit and delete \nexisting trips and create or add unscheduled trains  and trips in real-time during Revenue Service. \n20. The ATS subsystem shall track, record, and report for display all trips in the daily schedule, all trips \nthat are assigned to a train, all trips that are in progress, all trips that are completed, and all \nmodifications performed on a trip. \n21. The ATS subsystem shall include a function by whic h Transportation Controllers can trace a trip back \nto its original trip assignment and routing assignments.', metadata={'source': 'ats_fr_montreal_documents/File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf', 'page': 14, 'relevance_score': 0.000119598575}),
#  Document(page_content="Saturday/Sunday schedule is attempte d to be populated onto a weekday. \n8. The System shall have a GUI to import, manage and program schedules into the electronic calendar. \n9. The ATS subsystem timetable storage and datab ase function shall assemble and populate the daily \ntrain reporting sheet function when a time table is loaded in the ATS System. \n10. The ATS subsystem shall automatically load the dail y timetable with the electronic calendar function. \n11. The ATS subsystem shall allow Transportation Cont rollers to manually load a daily timetable by \nselecting a specific timetable database file. This feature will override the automatically loaded \ntimetable for that day. \n12. When the timetable is automatically  loaded by the calendar function, the full-day's train trip schedule \nshall be loaded from a Configurable star t time set by the Transportation Controller. \n13. The ATS subsystem shall have schedule editing tool s to modify the timetable database prior and", metadata={'source': 'ats_fr_montreal_documents/File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf', 'page': 13, 'relevance_score': 3.295573e-05}),
#  Document(page_content='Release 1.1- 4/25/2023 Release 1.2- 6/5/2023  \nSFMTA P-600 (11-21) – FTA A-211 SFMTA-2022-40-FTA \nKL                    n:\\ptc\\as2023\\2100392\\01654703.docx 2/6/23   \nspecified deviation tolerance before manual action (e .g., adjust trip departure time, reassign/swap trip, \ncancel trip) is required by the Transportation Controllers. \n3. The ATR function shall regulate train schedul e performance by maintaining schedule/headway \nadherence at each scheduled arrival and departure timepoint. \n4. The ATS subsystem shall import, accept and pr ocess timetable databases produced by Trapeze and \nOrbCAD. Interface requirements to these Third-Part y Systems are specified in Section 28 (Interface \nRequirements Specifications). \n5. The ATS subsystem shall store imported timetabl es from Third-Party Systems in its timetable \ndatabase. \n6. The ATS subsystem shall have a timetable storage and database function that supports the storage of', metadata={'source': 'ats_fr_montreal_documents/File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf', 'page': 13, 'relevance_score': 2.3552619e-05}),
#  Document(page_content='Specifications). \nu. Archive and timestamp all ATS events categorized as follows: \ni. all ATS commands and acti ons applied or executed manually or automatically \nii. all Interlocking status and changes \niii. all CBTC-driven status and changes', metadata={'source': 'ats_fr_montreal_documents/File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf', 'page': 2, 'relevance_score': 1.7502925e-05}),
#  Document(page_content='database. \n6. The ATS subsystem shall have a timetable storage and database function that supports the storage of \na minimum of one calendar year’s worth of schedules, comprised, and categorized as weekday, \nSaturday, Sunday, Holiday, and special event schedul es that can be populated (programmed) into an \nelectronic calendar (load-schedule-by-calendar-dat e function) up to one year in advance. \n7. The ATS subsystem shall use predetermined sche duling rules and apply automatic error checks \nwithout a user-confirmation when populating schedules into the electronic calendar. \na. An example of an error-check without user confirmation would be to prevent a weekday \nschedule from being populated onto a Saturday or Sunday. \nb. An example of an error-check that requi res a user confirmation would be when a \nSaturday/Sunday schedule is attempte d to be populated onto a weekday. \n8. The System shall have a GUI to import, manage and program schedules into the electronic calendar.', metadata={'source': 'ats_fr_montreal_documents/File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf', 'page': 13, 'relevance_score': 9.972941e-06}),
#  Document(page_content='point. \nc. A command allowing the user to modify prev iously assigned Dwell Times at a specific stop, \nstation, platform, or layover point. \nd. The Dwell Time assignment command shall enable  the user to specify the time period the \nDwell Time assignments are effective. Users sha ll also be able to specify the Dwell Time \nassignment is in effect indefinitely. \ne. The Dwell Time assignment and modification comm ands shall enable the user to specify \nwhich trains the assigned Dwell Times apply to . The commands shall provide the following \noptions: \ni. Specify individual trains identified by Consist ID. \nf. Specify the next “n” trains arriving at the stop, station, platform, or layover point, where “n” \nis a number of trains. . \ni. Specify all trains arriving at the stop, station, platform, or layover point. \ng. A message to Third-Party Systems through the API as described in Section 28 (Interface \nManagement Specifications) communicating the set Dwell Times for each stop, station,', metadata={'source': 'ats_fr_montreal_documents/File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf', 'page': 21, 'relevance_score': 9.741921e-06}),
#  Document(page_content='m. Implement Schedule Management functions. \nn. Implement Daily train reporting function. \no. Implement Automatic Train Regulation functions. \np. Set, display, and remove Temporary Speed R estrictions as specified in Section 16.3.1.9 \n(Temporary Speed Restrictions). \nq. Set, display, and remove Work Zones as specifi ed in Section 16.3.1.10 (Worker Protection) \nr. Prevent overloading of power and ventilation sections by restricting the number of trains that \ncan enter or operate in a de fined power/ventilation section. \ns. Interface with physical Emergency Stop Buttons, pl atform Local Control Panels and platform \nTrain Depart Consoles as specified in Secti on 16.3.1 (Train Control and Supervision). \nt. Interface with Third-Party Systems as specified in Section 28 (Interface Requirements \nSpecifications). \nu. Archive and timestamp all ATS events categorized as follows: \ni. all ATS commands and acti ons applied or executed manually or automatically', metadata={'source': 'ats_fr_montreal_documents/File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf', 'page': 2, 'relevance_score': 5.422219e-06}),
#  Document(page_content='physiques) du système à intervalle régulier au travers de l’interface avec l’Historien TCPE \n([VolC_PO1_S11]  - Volume C – Partie 1 - Section S11- Exigences Relatives aux interfaces CC). \n [R] L’ATS CBTC doit exporter les journaux applicatifs et du système d’exploitation de chacune des \nmachines (virtuelles ou physiques) à intervalle régulier au travers de l’interface avec l’Historien TCPE \n([VolC_PO1_S11]  - Volume C – Partie 1 - Section S11- Exigences Relatives aux interfaces CC). \n [R] Les événements archivés doivent être dans un format compréhensible par un utilisateur \npossédant le dictionnaire adéquat, permettant la traduction de la structure de données.  \n [L] Le dictionnaire permettant la traduction de la structure de données des événements doit être \nsoumis au Représentant désigné pour Vérification. \n [R] Dans le cas où l’ATS CBTC archive sur un support longue durée, les échanges avec le système', metadata={'source': 'ats_fr_montreal_documents/Montreal-Blue-Line-ATS-Specs-French.pdf', 'page': 61, 'relevance_score': 4.125012e-06})]

# %% [markdown]
# Now let's see what the reranked results look like:

# %%
pretty_print_docs(compressed_docs)
# Out:
# Document 1:
#
# tous les trains dont la course est complétée et changer le mode de départ des terminus à « hors
# service ».
# 5.7.6. MODIFIER LES HORAIRES HORS-LIGNE
#  [R] L’ATS CBTC doit permettre de visualiser une table horaire sans la charger pour l’exploitation
# (hors-ligne) via l’IPM.
#  [R] L’ATS CBTC doit fournir les outils nécessaires à l’IPM pour modifier un horaire hors-ligne et en
# vérifier la cohérence. Les mêmes commandes de modifications que pour un horaire chargé doivent
# être disponibles.
#  [R] L’ATS CBTC doit afficher une alarme à l’IPM lorsqu’une modification de l’horaire induit une
# incohérence.
#  [R] Lorsque les modifications faites à une table horaire hors-ligne sont valides, l’ATS CBTC doit
# permettre de sauvegarder les modifications pour utilisation ultérieure.
# 5.7.7. ARCHIVER LES DONNÉES D’EXPLOITATION
#  [R] L’ATS CBTC doit archiver toutes les données des horaires réalisés incluant, au minimum,
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# shall be loaded from a Configurable star t time set by the Transportation Controller.
# 13. The ATS subsystem shall have schedule editing tool s to modify the timetable database prior and
# during run time to account for potential changes or  during operations (i.e., changing timepoints, re-
# baselining the schedule, service imp acts/cancellations, special events).
# a. The ATS subsystem shall have functional interf aces to synchronize schedule changes made in
# ATS to OrbCAD as described in Section 28 (Interface Requirements Specifications).
# b. The ATS subsystem shall modify the timetabl e database during run time to process same-day
# schedule changes received from OrbCAD in or der to remain synchronized between OrbCAD
# and ATS.
# c. Contractor shall confer with SFMTA during the Design Phase and confirm the specific
# schedule editing tools needed to meet Contr act requirements and SFMTA’s operational needs
# as described in the Concept of Operations and Maintenance.
# ----------------------------------------------------------------------------------------------------
# Document 3:
#
# c) Manœuvre finale au terminus de destination (incluant le quai d’arrivée);
# d) Matricule opérateur;
# e) Origine;
# f) Destination;
# g) État de la course (future, en cours, terminée);
# h) Type de course (HLP, voyageur);
# i) Plage horaire (heure de début et de fin).
# 5.7.4. MODIFIER LA TABLE HORAIRE D’EXPLOITATION
#  [R] L’ATS CBTC doit s’assurer que pour toute modification effectuée à la table horaire, celle-ci reste
# opérationnelle et permet d’assurer le maintien des automatismes d’opération.
# 5.7.4.1. Modification de l’heure de départ
#  [R] L’ATS CBTC doit permettre de modifier l’heure de départ d’une course à venir via une commande
# de l’IPM tant que la séquence de départ n’est pas commencée.
#  [I] La séquence de départ correspond à l’ensemble des commandes requises pour autoriser le départ
# d’un train d’un terminus (ex. timbre de départ, itinéraire, indicateur de départ) qui est envoyé en
# ----------------------------------------------------------------------------------------------------
# Document 4:
#
# sauvegarder pour une réutilisation ultérieure en spécifiant le nom de la nouvelle table horaire.
# 5.7.5. GÉRER LES COURSES DE TRAIN
#  [R] L’ATS CBTC doit initier le processus de gestion automatique des trains dès qu’une table horaire
# est chargée et active ou qu’un terminus passe en mode de régulation par intervalle (ex. numérotation,
# acheminement des trains, gestion des départs, régulation).  Pour plus de détails sur les modes de
# départ « horaire » , voir 5.9 - Gérer les départs et manœuvres en terminus.
#  [R] L’ATS CBTC doit arrêter le processus de gestion automatique des trains dès qu’un terminus
# passe en mode « hors service », à l’exception des courses en cours qui doivent être complétées.
#  [R] Suite au déchargement de la table horaire, l’ATS CBTC doit supprimer le numéro de tournée de
# tous les trains dont la course est complétée et changer le mode de départ des terminus à « hors
# service ».
# 5.7.6. MODIFIER LES HORAIRES HORS-LIGNE
# ----------------------------------------------------------------------------------------------------
# Document 5:
#
# Release 1.1- 4/25/2023 Release 1.2- 6/5/2023
# SFMTA P-600 (11-21) – FTA A-212 SFMTA-2022-40-FTA
# KL                    n:\ptc\as2023\2100392\01654703.docx 2/6/23
# 14. The ATS timetable storage and database function shall use the loaded/ac tive ATS timetable to
# automatically:
# a. Generate, populate, and display the daily  train schedules for all lines/services
# b. Provide the schedule data to drive the automa tic ATS trip assignment function where trips get
# automatically assigned to trains that are located at the specified/defined train origination/entry
# points in the ATS monitored territory
# c. Provide the routing assignment based  on the train’s trip assignment
# 15. The schedule editing tools shall create new schedules by modifying existing schedules.
# 16. The schedule editing tools shall determine, modify , and save service routes, which establish routing
# through the System, to be applied and incorpor ated into new and existing schedules/services.
# ----------------------------------------------------------------------------------------------------
# Document 6:
#
# [R] L’ATS CBTC doit présenter la table horaire triée par ordre chronologique des heures de départ.
#  [R] L’ATS CBTC doit permettre de mettre à jour automatiquement le format et la couleur de champs
# de la table horaire en fonction de critères prédéfinis (ex. : type de course, état de la course).
#  [L] La définition des couleurs utilisées dans la table horaire pour les différents états/types de courses
# doit être soumise au Représentant désigné pour Vérification.
#  [R] L’ATS CBTC doit permettre d’afficher à l’IPM un horaire d’exploitation qui s’étend sur 2 jours (ex. :
# période d’exploitation de 5 h AM à 2 h AM le lendemain).
#  [R] L’ATS CBTC doit permettre, au minimum, de filtrer la table horaire en fonction des critères
# suivants :
# a) Numéro de tournée;
# b) Manœuvre initiale au terminus d’origine (incluant le quai de départ);
# c) Manœuvre finale au terminus de destination (incluant le quai d’arrivée);
# d) Matricule opérateur;
# e) Origine;
# f) Destination;
# ----------------------------------------------------------------------------------------------------
# Document 7:
#
# 5.7. GÉRER LES HORAIRES DE TRAIN ............................................................................. 29
# 5.7.1. RÉCUPÉRER LES HORAIRES D’EXPLOITATION .......................................................................... 29
# 5.7.2. CHARGER LA TABLE HORAIRE D’EXPLOITATION ....................................................................... 30
# 5.7.3. VISUALISER L’HORAIRE D’EXPLOITATION ................................................................................... 30
# 5.7.4. MODIFIER LA TABLE HORAIRE D’EXPLOITATION........................................................................ 31
# 5.7.5. GÉRER LES COURSES DE TRAIN .................................................................................................. 35
# 5.7.6. MODIFIER LES HORAIRES HORS-LIGNE ...................................................................................... 35
# ----------------------------------------------------------------------------------------------------
# Document 8:
#
# through the System, to be applied and incorpor ated into new and existing schedules/services.
# 17. The ATS timetable storage and database function shall have a repository for schedules and route
# definitions.
# 18. The ATS subsystem shall allow manual assignment or re-assignment of trips to any station platform
# or stop in CBTC Territory.
# 19. The ATS subsystem shall include a function by whic h Transportation Controllers can edit and delete
# existing trips and create or add unscheduled trains  and trips in real-time during Revenue Service.
# 20. The ATS subsystem shall track, record, and report for display all trips in the daily schedule, all trips
# that are assigned to a train, all trips that are in progress, all trips that are completed, and all
# modifications performed on a trip.
# 21. The ATS subsystem shall include a function by whic h Transportation Controllers can trace a trip back
# to its original trip assignment and routing assignments.
# ----------------------------------------------------------------------------------------------------
# Document 9:
#
# Saturday/Sunday schedule is attempte d to be populated onto a weekday.
# 8. The System shall have a GUI to import, manage and program schedules into the electronic calendar.
# 9. The ATS subsystem timetable storage and datab ase function shall assemble and populate the daily
# train reporting sheet function when a time table is loaded in the ATS System.
# 10. The ATS subsystem shall automatically load the dail y timetable with the electronic calendar function.
# 11. The ATS subsystem shall allow Transportation Cont rollers to manually load a daily timetable by
# selecting a specific timetable database file. This feature will override the automatically loaded
# timetable for that day.
# 12. When the timetable is automatically  loaded by the calendar function, the full-day's train trip schedule
# shall be loaded from a Configurable star t time set by the Transportation Controller.
# 13. The ATS subsystem shall have schedule editing tool s to modify the timetable database prior and
# ----------------------------------------------------------------------------------------------------
# Document 10:
#
# Release 1.1- 4/25/2023 Release 1.2- 6/5/2023
# SFMTA P-600 (11-21) – FTA A-211 SFMTA-2022-40-FTA
# KL                    n:\ptc\as2023\2100392\01654703.docx 2/6/23
# specified deviation tolerance before manual action (e .g., adjust trip departure time, reassign/swap trip,
# cancel trip) is required by the Transportation Controllers.
# 3. The ATR function shall regulate train schedul e performance by maintaining schedule/headway
# adherence at each scheduled arrival and departure timepoint.
# 4. The ATS subsystem shall import, accept and pr ocess timetable databases produced by Trapeze and
# OrbCAD. Interface requirements to these Third-Part y Systems are specified in Section 28 (Interface
# Requirements Specifications).
# 5. The ATS subsystem shall store imported timetabl es from Third-Party Systems in its timetable
# database.
# 6. The ATS subsystem shall have a timetable storage and database function that supports the storage of
# ----------------------------------------------------------------------------------------------------
# Document 11:
#
# Specifications).
# u. Archive and timestamp all ATS events categorized as follows:
# i. all ATS commands and acti ons applied or executed manually or automatically
# ii. all Interlocking status and changes
# iii. all CBTC-driven status and changes
# ----------------------------------------------------------------------------------------------------
# Document 12:
#
# database.
# 6. The ATS subsystem shall have a timetable storage and database function that supports the storage of
# a minimum of one calendar year’s worth of schedules, comprised, and categorized as weekday,
# Saturday, Sunday, Holiday, and special event schedul es that can be populated (programmed) into an
# electronic calendar (load-schedule-by-calendar-dat e function) up to one year in advance.
# 7. The ATS subsystem shall use predetermined sche duling rules and apply automatic error checks
# without a user-confirmation when populating schedules into the electronic calendar.
# a. An example of an error-check without user confirmation would be to prevent a weekday
# schedule from being populated onto a Saturday or Sunday.
# b. An example of an error-check that requi res a user confirmation would be when a
# Saturday/Sunday schedule is attempte d to be populated onto a weekday.
# 8. The System shall have a GUI to import, manage and program schedules into the electronic calendar.
# ----------------------------------------------------------------------------------------------------
# Document 13:
#
# point.
# c. A command allowing the user to modify prev iously assigned Dwell Times at a specific stop,
# station, platform, or layover point.
# d. The Dwell Time assignment command shall enable  the user to specify the time period the
# Dwell Time assignments are effective. Users sha ll also be able to specify the Dwell Time
# assignment is in effect indefinitely.
# e. The Dwell Time assignment and modification comm ands shall enable the user to specify
# which trains the assigned Dwell Times apply to . The commands shall provide the following
# options:
# i. Specify individual trains identified by Consist ID.
# f. Specify the next “n” trains arriving at the stop, station, platform, or layover point, where “n”
# is a number of trains. .
# i. Specify all trains arriving at the stop, station, platform, or layover point.
# g. A message to Third-Party Systems through the API as described in Section 28 (Interface
# Management Specifications) communicating the set Dwell Times for each stop, station,
# ----------------------------------------------------------------------------------------------------
# Document 14:
#
# m. Implement Schedule Management functions.
# n. Implement Daily train reporting function.
# o. Implement Automatic Train Regulation functions.
# p. Set, display, and remove Temporary Speed R estrictions as specified in Section 16.3.1.9
# (Temporary Speed Restrictions).
# q. Set, display, and remove Work Zones as specifi ed in Section 16.3.1.10 (Worker Protection)
# r. Prevent overloading of power and ventilation sections by restricting the number of trains that
# can enter or operate in a de fined power/ventilation section.
# s. Interface with physical Emergency Stop Buttons, pl atform Local Control Panels and platform
# Train Depart Consoles as specified in Secti on 16.3.1 (Train Control and Supervision).
# t. Interface with Third-Party Systems as specified in Section 28 (Interface Requirements
# Specifications).
# u. Archive and timestamp all ATS events categorized as follows:
# i. all ATS commands and acti ons applied or executed manually or automatically
# ----------------------------------------------------------------------------------------------------
# Document 15:
#
# physiques) du système à intervalle régulier au travers de l’interface avec l’Historien TCPE
# ([VolC_PO1_S11]  - Volume C – Partie 1 - Section S11- Exigences Relatives aux interfaces CC).
#  [R] L’ATS CBTC doit exporter les journaux applicatifs et du système d’exploitation de chacune des
# machines (virtuelles ou physiques) à intervalle régulier au travers de l’interface avec l’Historien TCPE
# ([VolC_PO1_S11]  - Volume C – Partie 1 - Section S11- Exigences Relatives aux interfaces CC).
#  [R] Les événements archivés doivent être dans un format compréhensible par un utilisateur
# possédant le dictionnaire adéquat, permettant la traduction de la structure de données.
#  [L] Le dictionnaire permettant la traduction de la structure de données des événements doit être
# soumis au Représentant désigné pour Vérification.
#  [R] Dans le cas où l’ATS CBTC archive sur un support longue durée, les échanges avec le système

# %% [markdown]
# Lastly, let's run our LLM query a final time with the reranked results:

# %%
query_grounded = "{}; Be sure to state the source (`source` and `page`) that you used; Translate the sources to English if needed; Compare the two sources in detail;  Documents: {}".format(query, compressed_docs)

result = llm([HumanMessage(content=query_grounded)]).content
print(f"Result:\n\n {result}")

#qa = RetrievalQA.from_chain_type(llm=llm,
#        chain_type="stuff",
#        retriever=compression_retriever)

#print(f"Result:\n\n {qa.run(query=query)}")
# Out:
# /ssd003/projects/aieng/public/rag_bootcamp/envs/rag_dataloaders/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Result:
#
#  I found some information on editing train timetables in two sources, which appear to be related documents. Both sources are in French, apparently originating from Montreal, Canada; I will provide an English translation of the requirements they outline.
#
# ## Source 1: File_6_-_SFMTA-2022-40-FTA-SAApndxA-ContractSpecs-RevAdd5_CHAP17.pdf
# This source's requirements for editing timetables are as follows:
#
# - The ATS (Automatic Train Supervision) subsystem should have tools to edit the timetable database both prior to and during runtime to account for potential changes, including same-day schedule changes.
# - The ATS subsystem should have functional interfaces to synchronize schedule changes made in ATS with a system called OrbCAD.
# - The ATS subsystem should modify the timetable database during operation to process same-day schedule changes received from OrbCAD, remaining synchronized.
# - The specific schedule editing tools needed to meet contract requirements and operational needs should be confirmed during the design phase.
# - The timetable storage and database function should use the loaded/active ATS timetable to automatically generate, populate, and display daily train schedules for all lines/services.
# - The schedule editing tools should create new schedules by modifying existing ones and determine, modify, and save service routes to be applied to new and existing schedules.
# - Said tools should also have a repository for schedule and route definitions.
# - The ATS subsystem should allow manual assignment or reassignment of trips to any station platform or stop within the CBTC territory.
# - The ATS subsystem should include a function for Transportation Controllers to edit, delete, and create unscheduled trains and trips in real-time during revenue service.
# - The ATS subsystem should track, record, and report all trips in the daily schedule, trips assigned to a train, trips in progress, completed trips, and any modifications performed on a trip.
# - Another function should enable Transportation Controllers to trace a trip back to its original assignment and routing.
# - The ATS timetable storage and database function should support the storage of at least one calendar year's worth of schedules (categorized by weekday, Saturday, Sunday, holidays, and special events) and be able to populate them into an electronic calendar.
# - The subsystem should use predetermined scheduling rules and perform error checks automatically (without user confirmation) when schedules are populated into the electronic calendar, preventing, for example, a weekday schedule from being loaded on a weekend.
# - A GUI (Graphical User Interface) should be implemented to import, manage, and program schedules into the electronic calendar.
#
# ## Source 2: Montreal-Blue-Line-ATS-Specs-French.pdf
# This source outlines the following requirements for timetable editing:
#
# - The ATS CBTC (Communications-Based Train Control) system should allow for the visualization of a timetable without loading it, for offline editing via the IPM (presumably a management interface of some kind).
# - The ATS CBTC should provide the IPM with the necessary tools to modify an offline timetable and verify its consistency. The same modification commands as for a loaded timetable should be available.
# - The system should display an alarm to the IPM when a timetable modification results in an inconsistency.
# - When modifications to an offline timetable are valid, the ATS CBTC should allow them to be saved for later use.
# - The ATS CBTC should ensure that any modifications made to the timetable do not hinder the operational functionality of the automatisms.
#
# ## Comparison
# Both sources outline requirements for editing timetables, but with different focuses. The first source emphasizes the need for real-time editing capabilities during operations, including manual assignment and reassignment of trips, with several features aimed at facilitating this. The second source, meanwhile, focuses more on offline editing, ensuring that the software provides the necessary tools and offers consistency checks.
#
# The first source deals mainly with the practical, runtime aspects of timetable editing, such as having the ability to quickly react to changes and synchronize them across different systems. The second source is more concerned with the technical aspects of offline editing, emphasizing the functionality and reliability of the tools provided for this purpose.
#
# While the first source touches on the need for functional interfaces and system synchronization, the second source goes into more detail about the actual data handling and archiving, emphasizing the comprehensibility of archived events and the ability to export application and system logs.
